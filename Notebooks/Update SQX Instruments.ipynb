# %%
from pathlib import Path
mt_path = Path("C:/") / "MetaTrader" / "MetaTrader 5 - 001"

# %% [raw]
# 1. Use MT5 Script to download Symbols data

# %%
import shutil
from _bootstrap import mq5_instruments_script
shutil.copy2(mq5_instruments_script['ex5'], mt_path / 'MQL5' / 'Scripts')
# Out:
# 'C:\\MetaTrader\\MetaTrader 5 - 001\\MQL5\\Scripts\\DX_Update_SQX_Instruments_information.ex5'

# %% [raw]
# 2. Locate folder Updated SQX Instruments Information (Imported from (XXX) (TimeOffset=0) (USD Account)) in the MT5 Files folder

# %%
from pathlib import Path
data_file = mt_path / "MQL5"  / "Files"
data_file = data_file / "Updated SQX Instruments Information (Imported from (Darwinex-Live) (TimeOffset=0) (USD Account))"
data_file = data_file / "StrategyQuantX" / "Updated Instrument information.xml"

from _bootstrap import update_instruments
update_instruments(data_file)
