# %%
from _bootstrap import sqx_tool
symbol="XAUUSD"
sqx_tool.newproject(sqx_tool.argparse.Namespace(
    symbol_dukascopy=f"{symbol}_darwinex",
    symbol_darwinex=f"{symbol}_dx_darwinex",
    timeframe="H1",
    direction="Long" if 1 else "Short",
))
